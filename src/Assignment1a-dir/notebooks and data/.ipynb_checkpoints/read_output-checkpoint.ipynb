# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import re
# %matplotlib notebook

# %%
column_names = ['test_id','text_length','pattern_length',
                'comparisons','wall_clock_time','cpu_time','optimization']
ss_output = pd.DataFrame(columns = column_names)
print(ss_output.columns)
# Out:
# Index(['test_id', 'text_length', 'pattern_length', 'comparisons',
#        'wall_clock_time', 'cpu_time', 'optimization'],
#       dtype='object')

# %%
#output = open('assignment1/Assignment1a-dir/outputs/searching_sequential.out', 'r')
count = 0
with open('../outputs/searching_sequential.out', 'r') as output:
    line=output.readline()
    while line != '':
        line = output.readline()
        #find start of test result
        if (line.find('Read') >= 0):
            count = count + 1
            test_no = int(re.findall('\d+',line)[0])
            line = output.readline()
            text_len = int(re.findall('\d+', line)[0])
            line = output.readline()
            patt_len = int(re.findall('\d+', line)[0])
            # skip next line which has result of search
            line = output.readline()
            line = output.readline()
            
            comparisons = int(re.findall('\d+', line)[0])
            line = output.readline()
            line = output.readline()
            wall_time = int(re.findall('\d+', line)[1])
            line = output.readline()
            cpu_time = float(re.findall('\d+\.\d+', line)[0])
            line = output.readline()
            
            if (count <= 20):
                optim = 'O2'
            else:
                optim = 'O0'
            
            new_row = {'test_id' : test_no, 'text_length' : text_len,
                      'pattern_length' : patt_len, 'comparisons' : comparisons,
                      'wall_clock_time' : wall_time, 
                       'cpu_time' : cpu_time,
                      'optimization': optim}
            ss_output = ss_output.append(new_row, ignore_index=True)
            
            

# for line in output:

#output.close()

# %%
ss_output.head()
# Out:
#   test_id text_length pattern_length comparisons wall_clock_time  \
# 0       0          10             10          10               0
# 1       1          20              5          80               0
# 2       2          50              2          98               0
# 3       3         100              1         100               0
# 4       4         100            100         100               0
#
#        cpu_time optimization
# 0  9.800000e-07           O2
# 1  7.730000e-07           O2
# 2  8.010000e-07           O2
# 3  8.610000e-07           O2
# 4  7.540000e-07           O2

# %%
ss_output['product'] = ss_output['text_length'] * ss_output['pattern_length']
ss_output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   test_id          40 non-null     object
#  1   text_length      40 non-null     object
#  2   pattern_length   40 non-null     object
#  3   comparisons      40 non-null     object
#  4   wall_clock_time  40 non-null     object
#  5   cpu_time         40 non-null     float64
#  6   optimization     40 non-null     object
#  7   product          40 non-null     object
# dtypes: float64(1), object(7)
# memory usage: 2.6+ KB

# %%
#import mpld3
#mpld3.enable_notebook()
x = 10 ** np.arange(2,10,2)
f, ax = plt.subplots(figsize=(8,8))


#ax.set_xticklabels(ss_output['product'].unique())
g=sns.scatterplot(x=ss_output['product'],
                  y=ss_output['cpu_time'],
                  hue=ss_output['optimization'])
#g.legend().texts[0].set_text('')
#g.legend().set_title('Compiler Optimization')
ax.legend().texts[0].set_text('Compiler Optimization')
ax.set_xlabel('Product')
ax.set_ylabel('CPU Execution Time')
ax.set(xscale='log')
# Out:
# <img src="data:image/png;base64,..." width="800">
# [None]

# %%
ss_output.to_csv('searching_sequential_out.csv',index=False,header=True)

# %%
savefig('ten_2_results.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-11accfd4d116> in <module>
# ----> 1 savefig('ten_2_results.png')
#
# NameError: name 'savefig' is not defined

# %%
f, ax = plt.subplots(figsize=(8,8))

ax.set_xlabel('No. Comparisons')
ax.set_ylabel('CPU Execution Time')
#ax.set_xticklabels(ss_output['product'].unique())
g=sns.regplot(x=ss_output['comparisons'],
                  y=ss_output[ss_output['optimization']=='O2']['cpu_time'])
g.show()
#g.legend().texts[0].set_text('')
#g.legend().set_title('Compiler Optimization')
#ax.legend().texts[0].set_text('Compiler Optimization')

#ax.set(xscale='log')
# Out:
# <img src="data:image/png;base64,..." width="800">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-574720722b61> in <module>
#       4 ax.set_ylabel('CPU Execution Time')
#       5 #ax.set_xticklabels(ss_output['product'].unique())
# ----> 6 g=sns.regplot(x=ss_output['comparisons'],
#       7                   y=ss_output[ss_output['optimization']=='O2']['cpu_time'], ci=None)
#       8 g.show()
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     803             scatter_kws=None, line_kws=None, ax=None):
#     804
# --> 805     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     806                                  scatter, fit_reg, ci, n_boot, units, seed,
#     807                                  order, logistic, lowess, robust, logx,
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     111         # Drop null observations
#     112         if dropna:
# --> 113             self.dropna("x", "y", "units", "x_partial", "y_partial")
#     114
#     115         # Regress nuisance variables out of the data
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in dropna(self, *vars)
#      59         vals = [getattr(self, var) for var in vars]
#      60         vals = [v for v in vals if v is not None]
# ---> 61         not_na = np.all(np.column_stack([pd.notnull(v) for v in vals]), axis=1)
#      62         for var in vars:
#      63             val = getattr(self, var)
#
# <__array_function__ internals> in column_stack(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\shape_base.py in column_stack(tup)
#     654             arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655         arrays.append(arr)
# --> 656     return _nx.concatenate(arrays, 1)
#     657
#     658
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 40 and the array at index 1 has size 20

# %%
ss_output[ss_output['optimization']=='O2']
# Out:
#    test_id text_length pattern_length comparisons wall_clock_time  \
# 0        0          10             10          10               0
# 1        1          20              5          80               0
# 2        2          50              2          98               0
# 3        3         100              1         100               0
# 4        4         100            100         100               0
# 5        5         200             50        7550               0
# 6        6         500             20        9620               0
# 7        7        1000             10        9910               0
# 8        8        1000           1000        1000               0
# 9        9        1600            625      610000               0
# 10      10        4000            250      937750               0
# 11      11     1000000              1     1000000               0
# 12      12       10000          10000       10000               0
# 13      13       15625           6400    59046400               0
# 14      14       80000           1250    98438750               0
# 15      15     1000000            100    99990100               0
# 16      16      100000         100000      100000               0
# 17      17      128000          78125  3896562500               3
# 18      18      250000          40000  8400040000               7
# 19      19     1000000          10000  9900010000               9
#
#         cpu_time optimization      product
# 0   9.800000e-07           O2          100
# 1   7.730000e-07           O2          100
# 2   8.010000e-07           O2          100
# 3   8.610000e-07           O2          100
# 4   7.540000e-07           O2        10000
# 5   2.490800e-05           O2        10000
# 6   9.653000e-06           O2        10000
# 7   9.730000e-06           O2        10000
# 8   1.569000e-06           O2      1000000
# 9   5.966560e-04           O2      1000000
# 10  8.829730e-04           O2      1000000
# 11  1.048764e-03           O2      1000000
# 12  9.929000e-06           O2    100000000
# 13  5.498031e-02           O2    100000000
# 14  9.245864e-02           O2    100000000
# 15  9.957399e-02           O2    100000000
# 16  9.203500e-05           O2  10000000000
# 17  3.579820e+00           O2  10000000000
# 18  7.720816e+00           O2  10000000000
# 19  9.098458e+00           O2  10000000000
